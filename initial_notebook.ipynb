# %% [markdown]
# # ARMSX2 Initial Notebook
#
# This is the initial Jupyter notebook for the ARMSX2 project.
#
# ## Overview
#
# This notebook serves as a starting point for data analysis and development within the ARMSX2 project.

# %% [markdown]
# ## Setup
#
# Import necessary libraries and configure the environment.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Environment setup complete!")

# %% [markdown]
# ## Getting Started
#
# Add your analysis and code here.

# %%
# Example: Create a simple dataset
data = {
    'name': ['Alice', 'Bob', 'Charlie'],
    'value': [10, 20, 30]
}

df = pd.DataFrame(data)
print(df)
